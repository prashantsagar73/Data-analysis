# %%
import pandas as pd

# %%
fortune=pd.read_csv('/Users/prashantsagar/Desktop/data /csvfile/fortune1000.csv',index_col="Rank")
sectors=fortune.groupby('Sector')
fortune
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
type(fortune)
# Out:
# pandas.core.frame.DataFrame

# %%
type(sectors)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
sectors.first()
# it show the result according to sector list
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                           Boeing
# Apparel                                         Nike
# Business Services                      ManpowerGroup
# Chemicals                               Dow Chemical
# Energy                                   Exxon Mobil
# Engineering & Construction                     Fluor
# Financials                        Berkshire Hathaway
# Food and Drug Stores                      CVS Health
# Food, Beverages & Tobacco     Archer Daniels Midland
# Health Care                                 McKesson
# Hotels, Resturants & Leisure              McDonald’s
# Household Products                  Procter & Gamble
# Industrials                         General Electric
# Materials                                      Alcoa
# Media                                         Disney
# Motor Vehicles & Parts                General Motors
# ...

# %%
sectors.last()
# Out:
#                                                         Company  \
# Sector
# Aerospace & Defense                       Delta Tucker Holdings
# Apparel                                                   Guess
# Business Services                         DeVry Education Group
# Chemicals                                           H.B. Fuller
# Energy                                Portland General Electric
# Engineering & Construction                         MDC Holdings
# Financials                           New York Community Bancorp
# Food and Drug Stores                                     Fred’s
# Food, Beverages & Tobacco            Alliance One International
# Health Care                                  Providence Service
# Hotels, Resturants & Leisure                            Wendy’s
# Household Products                                       Revlon
# Industrials                                   Briggs & Stratton
# ...

# %%
sectors.groups
# Out:
# {'Aerospace & Defense': Int64Index([ 24,  45,  60,  88, 118, 120, 209, 245, 282, 378, 389, 490, 560,
#              605, 785, 788, 836, 903, 958, 987],
#             dtype='int64', name='Rank'),
#  'Apparel': Int64Index([91, 231, 340, 354, 448, 547, 575, 597, 683, 695, 726, 794, 877,
#              882, 917],
#             dtype='int64', name='Rank'),
#  'Business Services': Int64Index([144, 186, 199, 204, 221, 248, 249, 294, 307, 312, 355, 392, 404,
#              440, 467, 468, 481, 485, 492, 503, 545, 626, 635, 652, 677, 694,
#              714, 729, 734, 735, 737, 744, 767, 776, 777, 783, 791, 792, 796,
#              801, 803, 816, 819, 820, 869, 870, 886, 939, 951, 952, 993],
#             dtype='int64', name='Rank'),
#  'Chemicals': Int64Index([ 56, 101, 182, 189, 206, 253, 262, 277, 288, 296, 316, 538, 549,
#              555, 566, 580, 613, 624, 654, 668, 717, 720, 724, 758, 761, 829,
#              865, 898, 934, 949],
#             dtype='int64', name='Rank'),
# ...

# %%
fortune.loc[24]
# Out:
# Company                     Boeing
# Sector         Aerospace & Defense
# Industry     Aerospace and Defense
# Location               Chicago, IL
# Revenue                      96114
# Profits                       5176
# Employees                   161400
# Name: 24, dtype: object

# %%
fortune=pd.read_csv('/Users/prashantsagar/Desktop/data /csvfile/fortune1000.csv',index_col="Rank")
sectors=fortune.groupby('Sector')
fortune
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %% [markdown]
# # get_group method

# %%
sectors.get_group("Energy")
# it show df in sector which contain only energy
# Out:
#                         Company  Sector                      Industry  \
# Rank
# 2                   Exxon Mobil  Energy            Petroleum Refining
# 14                      Chevron  Energy            Petroleum Refining
# 30                  Phillips 66  Energy            Petroleum Refining
# 32                Valero Energy  Energy            Petroleum Refining
# 42           Marathon Petroleum  Energy            Petroleum Refining
# ...                         ...     ...                           ...
# 981                  WPX Energy  Energy  Mining, Crude-Oil Production
# 983    Adams Resources & Energy  Energy            Petroleum Refining
# 995                   EP Energy  Energy  Mining, Crude-Oil Production
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
#
#              Location  Revenue  Profits  Employees
# Rank
# 2          Irving, TX   246204    16150      75600
# ...

# %%
sectors.max()
# it showas the df according mxx(which contain higest value)
sectors.min()
# it shows th df according min 
sectors.mean()
# mena 
sectors.sum()
# sum
# Out:
#                               Revenue  Profits  Employees
# Sector
# Aerospace & Defense            357940    28742     968057
# Apparel                         95968     8236     346397
# Business Services              272195    28227    1361050
# Chemicals                      243897    22628     463651
# Energy                        1517809   -73447    1188927
# Engineering & Construction     153983     5304     406708
# Financials                    2217159   260209    3359948
# Food and Drug Stores           483769    16759    1395398
# Food, Beverages & Tobacco      555967    51417    1211632
# Health Care                   1614707   106114    2678289
# Hotels, Resturants & Leisure   169546    20697    2484245
# Household Products             234737    14428     646038
# Industrials                    497581    20764    1545229
# Materials                      259145     4428     638123
# Media                          220764    24347     550314
# ...

# %%
sectors.get_group('Apparel')["Profits"].sum()
# altetnate method for specofic columns
# Out:
# 8236

# %%
# for a any row
sectors["Company"].sum()
sectors['Profits'].mean()
sectors['Revenue'].max()
for multi row
sectors[['Profits','Revenue']].mean()
# Out:
#                                   Profits       Revenue
# Sector
# Aerospace & Defense           1437.100000  17897.000000
# Apparel                        549.066667   6397.866667
# Business Services              553.470588   5337.156863
# Chemicals                      754.266667   8129.900000
# Energy                        -602.024590  12441.057377
# Engineering & Construction     204.000000   5922.423077
# Financials                    1872.007194  15950.784173
# Food and Drug Stores          1117.266667  32251.266667
# Food, Beverages & Tobacco     1195.744186  12929.465116
# Health Care                   1414.853333  21529.426667
# Hotels, Resturants & Leisure   827.880000   6781.840000
# Household Products             515.285714   8383.464286
# Industrials                    451.391304  10816.978261
# Materials                      102.976744   6026.627907
# Media                          973.880000   8830.560000
# Motor Vehicles & Parts        1079.083333  20105.833333
# ...

# %% [markdown]
# # grouping by multiple columns

# %%
fortune=pd.read_csv('/Users/prashantsagar/Desktop/data /csvfile/fortune1000.csv',index_col="Rank")
sectors=fortune.groupby(['Sector','Location'])
fortune
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
sectors.sum()
# much more function we applie here
# Out:
#                                        Revenue  Profits  Employees
# Sector              Location
# Aerospace & Defense Berwyn, PA            3889      239      15153
#                     Bethesda, MD         46132     3605     126000
#                     Cedar Rapids, IA      5262      686      19500
#                     Charlotte, NC         2264      146       8400
#                     Chicago, IL          96114     5176     161400
# ...                                        ...      ...        ...
# Wholesalers         St. Louis, MO         6110       91       8300
#                     Tempe, AZ             5373       76       5761
#                     The Woodlands, TX     3949       20       2450
#                     Tulsa, OK            16802       17       3100
#                     Waltham, MA          10315       44       1890
#
# [750 rows x 3 columns]

# %%
sectors['Location'].sum()
# Out:
# Sector               Location
# Aerospace & Defense  Berwyn, PA                  Berwyn, PA
#                      Bethesda, MD              Bethesda, MD
#                      Cedar Rapids, IA      Cedar Rapids, IA
#                      Charlotte, NC            Charlotte, NC
#                      Chicago, IL                Chicago, IL
#                                                 ...
# Wholesalers          St. Louis, MO            St. Louis, MO
#                      Tempe, AZ                    Tempe, AZ
#                      The Woodlands, TX    The Woodlands, TX
#                      Tulsa, OK                    Tulsa, OK
#                      Waltham, MA                Waltham, MA
# Name: Location, Length: 750, dtype: object

# %% [markdown]
# # agg method

# %%
fortune=pd.read_csv('/Users/prashantsagar/Desktop/data /csvfile/fortune1000.csv',index_col="Rank")
sectors=fortune.groupby('Sector')
fortune
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
sectors.agg({'Employees': 'mean',
              'Company':'min',
              'Location':'max'})
# Out:
#                                  Employees                        Company  \
# Sector
# Aerospace & Defense           48402.850000                  B/E Aerospace
# Apparel                       23093.133333                       Carter’s
# Business Services             26687.254902                 ABM Industries
# Chemicals                     15455.033333                    A. Schulman
# Energy                         9745.303279                            AES
# Engineering & Construction    15642.615385                          AECOM
# Financials                    24172.287770                            AIG
# Food and Drug Stores          93026.533333                     CVS Health
# Food, Beverages & Tobacco     28177.488372     Alliance One International
# Health Care                   35710.520000                         AbbVie
# Hotels, Resturants & Leisure  99369.800000                Bloomin’ Brands
# Household Products            23072.785714                  Avon Products
# ...

# %%
sectors.agg(['sum','mean','max'])
# Out:
#                               Revenue                       Profits  \
#                                   sum          mean     max     sum
# Sector
# Aerospace & Defense            357940  17897.000000   96114   28742
# Apparel                         95968   6397.866667   30601    8236
# Business Services              272195   5337.156863   19330   28227
# Chemicals                      243897   8129.900000   48778   22628
# Energy                        1517809  12441.057377  246204  -73447
# Engineering & Construction     153983   5922.423077   18114    5304
# Financials                    2217159  15950.784173  210821  260209
# Food and Drug Stores           483769  32251.266667  153290   16759
# Food, Beverages & Tobacco      555967  12929.465116   67702   51417
# Health Care                   1614707  21529.426667  181241  106114
# Hotels, Resturants & Leisure   169546   6781.840000   25413   20697
# Household Products             234737   8383.464286   78756   14428
# ...

# %% [markdown]
# # illetrating though group

# %%
df=pd.DataFrame(columns=fortune.columns)
df
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
for sector, data in sectors:
    higest_revenue_value_in_group= data.nlargest(1,'Revenue')
    df=df.append( higest_revenue_value_in_group)

# %%
df
# Out:
#                     Company                        Sector  \
# 24                   Boeing           Aerospace & Defense
# 91                     Nike                       Apparel
# 144           ManpowerGroup             Business Services
# 56             Dow Chemical                     Chemicals
# 2               Exxon Mobil                        Energy
# 155                   Fluor    Engineering & Construction
# 4        Berkshire Hathaway                    Financials
# 7                CVS Health          Food and Drug Stores
# 41   Archer Daniels Midland     Food, Beverages & Tobacco
# 5                  McKesson                   Health Care
# 109              McDonald’s  Hotels, Resturants & Leisure
# 34         Procter & Gamble            Household Products
# 11         General Electric                   Industrials
# 126                   Alcoa                     Materials
# 53                   Disney                         Media
# ...

# %%
city=fortune.groupby("Sector")
df=pd.DataFrame(columns=fortune.columns)
df
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
for cit, data in city:
    higest_value=data.nlargest(1,"Profits")
    df= df.append(higest_value)

# %%
df
# Out:
#                      Company                        Sector  \
# 45       United Technologies           Aerospace & Defense
# 91                      Nike                       Apparel
# 204                     Visa             Business Services
# 56              Dow Chemical                     Chemicals
# 2                Exxon Mobil                        Energy
# 301                   Lennar    Engineering & Construction
# 23         J.P. Morgan Chase                    Financials
# 7                 CVS Health          Food and Drug Stores
# 62                 Coca-Cola     Food, Beverages & Tobacco
# 86           Gilead Sciences                   Health Care
# 534    Caesars Entertainment  Hotels, Resturants & Leisure
# 34          Procter & Gamble            Household Products
# 93                        3M                   Industrials
# 616                      USG                     Materials
# 53                    Disney                         Media
# ...
